# %% [markdown]
# # Analyse du catalogue Netflix - Projet de Data Cleaning
#
# ## Contexte du projet
# Ce projet fait partie de mon parcours d'apprentissage en data analysis. L'objectif est de maîtriser les techniques fondamentales de **nettoyage et manipulation de données** avec pandas, avant d'aborder la visualisation dans mes prochains projets.
#
# ## Objectifs pédagogiques
# - Gérer les problèmes d'encodage lors de l'import de fichiers CSV
# - Nettoyer et transformer des colonnes (types, valeurs manquantes, formats)
# - Normaliser des données multi-valuées (colonnes contenant des listes séparées par virgules)
# - Créer des features temporelles à partir de dates
# - Réaliser une analyse exploratoire basique
#
# ## Dataset
# Le dataset contient 8809 titres Netflix (films et séries) avec des informations sur les réalisateurs, le casting, les pays de production, les dates d'ajout, les durées et les catégories.
#
# **Source** : Netflix Titles Dataset
# **Période** : Janvier 2026
# **Niveau** : Apprentissage - Focus sur data cleaning

# %% [markdown]
# <h1> Data Cleaning et data modeling</h1>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Phase 1 : Import et découverte des données
#
# ### Étape 1 : Import du fichier CSV
# Je commence par importer le dataset. Si un problème d'encodage survient, je teste différents encodages (UTF-8, latin-1, ISO-8859-1).

# %%
#Import DataSet Netflix
df = pd.read_csv('netflix_titles.csv', encoding='latin')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  ... Unnamed: 16  \
# 0  September 25, 2021          2020  PG-13     90 min  ...         NaN
# ...

# %% [markdown]
# ### Étape 2 : Création d'une copie de travail
# Je crée une copie du DataFrame original pour conserver les données brutes intactes.

# %%
# Création copy
df_wip = df.copy()
df_wip.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  ... Unnamed: 16  \
# 0  September 25, 2021          2020  PG-13     90 min  ...         NaN
# ...

# %% [markdown]
# ### Étape 3 : Nettoyage initial
# Je vérifie et supprime les colonnes vides ("Unnamed"), puis je définis `show_id` comme index après avoir vérifié qu'il ne contient ni doublons ni valeurs manquantes.

# %%
# Suppression colonnes Unnamed
df_wip = df_wip[["show_id", "type", "title", "director", "cast", "country", "date_added", "release_year", "rating", "duration", "listed_in", "description"]]
df_wip.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# Verification doublons & valeurs manquantes pour colonne 'Show Id'
print(df['show_id'].isnull().any())
print(df['show_id'].duplicated().any())
# Out:
# False
# False

# %%
# Definir index "Show Id"
df_wip.set_index('show_id', inplace=True)
df_wip.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# ...

# %%
# Information DataSet
print(df_wip.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8809 entries, s1 to s8809
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8809 non-null   object
#  1   title         8809 non-null   object
#  2   director      6175 non-null   object
#  3   cast          7984 non-null   object
#  4   country       7978 non-null   object
#  5   date_added    8799 non-null   object
#  6   release_year  8809 non-null   int64
#  7   rating        8805 non-null   object
#  8   duration      8806 non-null   object
#  9   listed_in     8809 non-null   object
#  10  description   8809 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 825.8+ KB
# None

# %%
# Information DataSet 2
df_wip.shape
# Out:
# (8809, 11)

# %% [markdown]
# ## Phase 2 : Traitement des colonnes temporelles
#
# ### Problème identifié
# La colonne `date_added` est au format texte ("September 25, 2021") alors qu'elle devrait être en datetime pour permettre des analyses temporelles.
#
# ### Solution
# J'utilise `pd.to_datetime()` avec le paramètre `errors='coerce'` pour convertir les dates invalides en NaT (Not a Time) plutôt que de générer une erreur.

# %%
# Visualisation colonne "date_added"
df_wip.loc[:, 'date_added']
# Out:
# show_id
# s1       September 25, 2021
# s2       September 24, 2021
# s3       September 24, 2021
# s4       September 24, 2021
# s5       September 24, 2021
#                 ...
# s8805      November 1, 2019
# s8806      January 11, 2020
# s8807         March 2, 2019
# s8808         April 5, 2024
# s8809         April 5, 2024
# Name: date_added, Length: 8809, dtype: object

# %%
# Transformation colonne "date_added" en format DateTime
df_wip['date_added'] = pd.to_datetime(df_wip['date_added'],
                                      format='%B %d, %Y',
                                      errors='coerce')
df_wip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8809 entries, s1 to s8809
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8809 non-null   object
#  1   title         8809 non-null   object
#  2   director      6175 non-null   object
#  3   cast          7984 non-null   object
#  4   country       7978 non-null   object
#  5   date_added    8711 non-null   datetime64[ns]
#  6   release_year  8809 non-null   int64
#  7   rating        8805 non-null   object
#  8   duration      8806 non-null   object
#  9   listed_in     8809 non-null   object
#  10  description   8809 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Phase 3 : Restructuration de la colonne Duration
#
# ### Challenge
# La colonne `duration` mélange deux types d'informations :
# - Pour les films : durée en minutes (ex: "90 min")
# - Pour les séries : nombre de saisons (ex: "2 Seasons")
#
# Cette structure rend impossible toute analyse statistique sur les durées. Je dois séparer ces informations en deux colonnes distinctes.
#
# ### Approche
# 1. Vérifier que la colonne `type` ne contient que 'Movie' et 'TV Show'
# 2. Analyser le format des valeurs dans `duration`
# 3. Créer deux nouvelles colonnes numériques :
#    - `duration_movies` : durée en minutes (float) pour les films
#    - `duration_tv_show` : nombre de saisons (float) pour les séries
# 4. Supprimer l'ancienne colonne `duration`

# %%
# Verification valeurs colonne "type"
df_wip['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
# Analyse colonne 'duration'

df_wip['duration'].head(10)
# Out:
# show_id
# s1        90 min
# s2     2 Seasons
# s3      1 Season
# s4      1 Season
# s5     2 Seasons
# s6      1 Season
# s7        91 min
# s8       125 min
# s9     9 Seasons
# s10      104 min
# Name: duration, dtype: object

# %%
df_wip.groupby("duration")['type'].value_counts()
# Out:
# duration    type
# 1 Season    TV Show    1794
# 10 Seasons  TV Show       7
# 10 min      Movie         1
# 100 min     Movie       108
# 101 min     Movie       116
#                        ...
# 95 min      Movie       137
# 96 min      Movie       130
# 97 min      Movie       146
# 98 min      Movie       120
# 99 min      Movie       118
# Name: count, Length: 220, dtype: int64

# %%
df_wip.groupby("duration")['type'].unique()
# Out:
# duration
# 1 Season      [TV Show]
# 10 Seasons    [TV Show]
# 10 min          [Movie]
# 100 min         [Movie]
# 101 min         [Movie]
#                 ...
# 95 min          [Movie]
# 96 min          [Movie]
# 97 min          [Movie]
# 98 min          [Movie]
# 99 min          [Movie]
# Name: type, Length: 220, dtype: object

# %% [markdown]
# ## Phase 4 : Normalisation des colonnes multi-valuées
#
# ### Problématique
# Certaines colonnes comme `country`, `cast` et `listed_in` contiennent plusieurs valeurs séparées par des virgules dans une seule cellule. Par exemple :
# - country : "United States, United Kingdom, France"
# - cast : "Adam Sandler, Drew Barrymore, Rob Schneider"
#
# Cette structure empêche de répondre à des questions comme "Quels sont les acteurs les plus présents ?" ou "Quel pays produit le plus de documentaires ?".
#
# ### Solution : la méthode `.explode()`
# Je vais créer des DataFrames annexes où chaque valeur occupe une ligne distincte. Cela permet de faire des analyses par pays, acteur ou catégorie.
#
# **Processus** :
# 1. Transformer les chaînes en listes avec `str.split(',')`
# 2. Utiliser `.explode()` pour créer une ligne par élément de liste
# 3. Créer 3 DataFrames auxiliaires : `countries_exploded`, `categories_exploded`, `cast_list`

# %%
# Création colonne "duration_movies" avec valeur numérique durée des films.
df_wip['duration_movies'] = df_wip[df_wip['type'] == 'Movie']['duration'].str.extract('(\d+)').astype(float)
df_wip['duration_movies']
# Out:
# show_id
# s1        90.0
# s2         NaN
# s3         NaN
# s4         NaN
# s5         NaN
#          ...
# s8805     88.0
# s8806     88.0
# s8807    111.0
# s8808      NaN
# s8809    110.0
# Name: duration_movies, Length: 8809, dtype: float64

# %%
# Création colonne 'duration_tv_show' avec valeur numérique du nombre de saisons.
df_wip['duration_tv_show'] = df_wip[df_wip['type'] == 'TV Show']['duration'].str.extract('(\d+)').astype(float)
df_wip['duration_tv_show']
# Out:
# show_id
# s1       NaN
# s2       2.0
# s3       1.0
# s4       1.0
# s5       2.0
#         ...
# s8805    NaN
# s8806    NaN
# s8807    NaN
# s8808    1.0
# s8809    NaN
# Name: duration_tv_show, Length: 8809, dtype: float64

# %%
# Suppression colonne 'duration'
df_wip.drop(columns = 'duration', inplace=True)
df_wip.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#         date_added  release_year rating  \
# show_id
# s1      2021-09-25          2020  PG-13
# s2      2021-09-24          2021  TV-MA
# ...

# %%
# Visualisation

df_wip['country'].head(10).to_frame()
# Out:
#                                                    country
# show_id
# s1                                           United States
# s2                                            South Africa
# s3                                                     NaN
# s4                                                     NaN
# s5                                                   India
# s6                                                     NaN
# s7                                                     NaN
# s8       United States, Ghana, Burkina Faso, United Kin...
# s9                                          United Kingdom
# s10                                          United States

# %%
# Création DataFrame 'countries_exploded' sur "countries"
df_wip['countries'] = df_wip['country'].str.split(',')

# Nettoyage des espaces dans chaque élément de la liste
df_wip['countries'] = df_wip['countries'].apply(
    lambda x: [i.strip() for i in x] if isinstance(x, list) else x
)

countries_exploded = df_wip.explode('countries')
countries_exploded = countries_exploded[['countries']]

# %%
# Création DataFrame 'categories_exploded' sur "listed_in"
df_wip['listed_in_list'] = df_wip['listed_in'].str.split(',')
categories_exploded = df_wip.explode('listed_in_list')
categories_exploded = categories_exploded['listed_in_list']
categories_exploded.unique()
# Out:
# array(['Documentaries', 'International TV Shows', ' TV Dramas',
#        ' TV Mysteries', 'Crime TV Shows', ' International TV Shows',
#        ' TV Action & Adventure', 'Docuseries', ' Reality TV',
#        ' Romantic TV Shows', ' TV Comedies', 'TV Dramas', ' TV Horror',
#        'Children & Family Movies', 'Dramas', ' Independent Movies',
#        ' International Movies', 'British TV Shows', 'Comedies', ' Dramas',
#        ' Docuseries', ' Comedies', ' Crime TV Shows', 'TV Comedies',
#        ' Spanish-Language TV Shows', 'Thrillers', ' Romantic Movies',
#        ' Music & Musicals', 'Horror Movies', ' Sci-Fi & Fantasy',
#        ' TV Thrillers', "Kids' TV", ' Thrillers', 'Action & Adventure',
#        ' TV Sci-Fi & Fantasy', ' Classic Movies', ' Horror Movies',
#        ' Anime Features', 'Reality TV', ' Sports Movies', 'Anime Series',
#        " Kids' TV", 'International Movies', ' Korean TV Shows',
#        'Sci-Fi & Fantasy', ' Science & Nature TV', ' Teen TV Shows',
# ...

# %%
# Création DataFrame 'cast_list' sur "cast"
df_wip['cast_list'] = df_wip['cast'].str.split(',')
cast_list = df_wip.explode('cast_list')
cast_list = cast_list['cast_list']
cast_list.unique()
# Out:
# array([nan, 'Ama Qamata', ' Khosi Ngema', ..., ' Petr Drozda',
#        ' John Comer', ' Benedetta Degli Innocenti'],
#       shape=(39324,), dtype=object)

# %%
# Sauvegarde DataFrame to CSV
countries_exploded.to_csv('countries_exploded.csv')
categories_exploded.to_csv('categories_exploded.csv')
cast_list.to_csv('cast_list.csv')

# %%
# Supression colonne 'country', 'cast', 'listed_in'
df_wip.drop(columns=['countries','listed_in_list','cast_list'], inplace=True)
df_wip.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#         date_added  release_year rating  \
# show_id
# s1      2021-09-25          2020  PG-13
# s2      2021-09-24          2021  TV-MA
# ...

# %% [markdown]
# ### Extraction de features temporelles
#
# Maintenant que `date_added` est au format datetime, je peux extraire des informations temporelles sous forme de colonnes séparées. Ces nouvelles features permettront d'analyser les patterns d'ajout de contenu sur Netflix.
#
# **Features créées** :
# - `year_added` : Année d'ajout (pour analyser les tendances annuelles)
# - `month_added` : Mois d'ajout (pour détecter des saisonnalités)
# - `day_of_the_week_added` : Jour de la semaine d'ajout en format numérique (0=lundi, 6=dimanche)
#
# Ces colonnes permettent de répondre à des questions comme "Netflix ajoute-t-il plus de contenu certains jours de la semaine ?" ou "Y a-t-il eu une accélération des ajouts ces dernières années ?".
#
# **Méthode** : J'utilise les accesseurs datetime de pandas (`.dt.year`, `.dt.month`, `.dt.dayofweek`) qui extraient automatiquement les composantes temporelles.

# %%
df_wip['year_added'] = df_wip['date_added'].dt.year
df_wip['month_added'] = df_wip['date_added'].dt.month
df_wip['day_of_the_week_added'] = df_wip['date_added'].dt.dayofweek

df_wip[['year_added', 'month_added', 'day_of_the_week_added']].head()
# Out:
#          year_added  month_added  day_of_the_week_added
# show_id
# s1           2021.0          9.0                    5.0
# s2           2021.0          9.0                    4.0
# s3           2021.0          9.0                    4.0
# s4           2021.0          9.0                    4.0
# s5           2021.0          9.0                    4.0

# %% [markdown]
# ## 💾 Export du DataFrame nettoyé
#
# Maintenant que toutes les opérations de data cleaning sont terminées, j'exporte le DataFrame dans un nouveau fichier CSV. Cela me permet de :
# - Séparer clairement les phases de cleaning et d'analyse
# - Réutiliser ces données nettoyées dans d'autres projets
# - Gagner du temps en évitant de refaire le preprocessing à chaque analyse
#
# **Fichier exporté** : `netflix_titles_cleaned.csv`
# **Encodage** : UTF-8 pour garantir la compatibilité
# **Index** : Conservé car `show_id` sert d'identifiant unique

# %%
# Export du DataFrame nettoyé
df_wip.to_csv('netflix_titles_cleaned.csv', encoding='utf-8', index=True)

# Vérification de l'export
print(f"Export réussi : {len(df_wip)} lignes et {len(df_wip.columns)} colonnes")
print(f"Colonnes exportées : {list(df_wip.columns)}")
# Out:
# Export réussi : 8809 lignes et 15 colonnes
# Colonnes exportées : ['type', 'title', 'director', 'cast', 'country', 'date_added', 'release_year', 'rating', 'listed_in', 'description', 'duration_movies', 'duration_tv_show', 'year_added', 'month_added', 'day_of_the_week_added']

# %% [markdown]
# ## Phase 5 : Analyse exploratoire des données
#
# Maintenant que les données sont nettoyées et structurées, je peux répondre à des questions business sur le catalogue Netflix. Cette analyse exploratoire permet de découvrir des tendances et des patterns dans les données.
#
# **Note** : Cette analyse est purement statistique (sans visualisation). Les graphiques seront ajoutés dans la version 2 de ce projet, une fois que j'aurai appris matplotlib et seaborn.

# %% [markdown]
# ### Questions sur la composition du catalogue

# %%
# combien de shows sont présent dans le dataset
len(df_wip)
# Out:
# 8809

# %%
# Répartition type "Movie" & "TV Show" dans la colonne "Type"
df_wip['type'].value_counts()
# Out:
# type
# Movie      6132
# TV Show    2677
# Name: count, dtype: int64

# %% [markdown]
# ### Questions sur les tendances temporelles

# %%
# Répartition des ajouts en fonction de l'année
df_wip['year_added'].value_counts()
# Out:
# year_added
# 2019.0    1999
# 2020.0    1878
# 2018.0    1625
# 2021.0    1498
# 2017.0    1164
# 2016.0     418
# 2015.0      73
# 2014.0      23
# 2011.0      13
# 2013.0      10
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2024.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
# Quelle est la répartition des ajouts en fonction du jour de la semaine ?
df_wip['day_of_the_week_added'].value_counts()
# Out:
# day_of_the_week_added
# 4.0    2478
# 3.0    1387
# 2.0    1276
# 1.0    1182
# 0.0     845
# 5.0     803
# 6.0     740
# Name: count, dtype: int64

# %% [markdown]
# ### Questions sur le contenu et les acteurs

# %%
# Top 5 des catégories de shows les plus ajoutées
categories_exploded.value_counts().head(5)
# Out:
# listed_in_list
#  International Movies    2624
# Dramas                   1600
# Comedies                 1210
# Action & Adventure        859
# Documentaries             829
# Name: count, dtype: int64

# %%
# Top 5 des comédiens les plus plébiscités aux Etats-Unis.

merge_cast = pd.merge(cast_list, df_wip, how='inner', left_index=True, right_index=True)
usa_data = merge_cast[merge_cast['country'].str.contains('United States', na=False)]
usa_data['cast_list'].value_counts().head(5)
# Out:
# cast_list
# Adam Sandler        20
#  Fred Tatasciore    19
#  Molly Shannon      16
#  Alfred Molina      15
#  Tara Strong        15
# Name: count, dtype: int64

# %%
# Pays plus gros producteur de documentaires

merge_countries = pd.merge(countries_exploded, df_wip, how='inner', left_index=True, right_index=True)
countries_data = merge_countries[merge_countries['listed_in'].str.contains('Documentaries', na=False)]
countries_data['countries'].value_counts().head(5)
# Out:
# countries
# United States     453
# United Kingdom    103
#  United States     59
# Canada             33
# France             27
# Name: count, dtype: int64

# %% [markdown]
# ### Questions statistiques

# %%
# Moyenne des saisons par les séries
df_wip['duration_tv_show'].mean()
# Out:
# np.float64(1.7646619350018677)

# %%
# Distribution des films en fonction de leur durée (quartiles)
df_wip['duration_movies'].describe()
# Out:
# count    6129.000000
# mean       99.578887
# std        28.288598
# min         3.000000
# 25%        87.000000
# 50%        98.000000
# 75%       114.000000
# max       312.000000
# Name: duration_movies, dtype: float64

# %%
# Film avec pour thématique la drogue

drug_show = df_wip[df_wip['description'].str.contains('drug')]
print(len(drug_show))
# Out:
# 158
